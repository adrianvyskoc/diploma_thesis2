# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
subject_points = pd.read_excel('datasets/subject_points/FIIT_2015_2016_ph.xlsx', engine='openpyxl')
#admissions_bachelor.set_index('AIS_ID', inplace = True)
#admissions_bachelor.dropna(inplace=True)

# %%
sum = subject_points[['KOD', 'AIS_ID', 'STUDENT', 'BODY_PH']].groupby(by=['AIS_ID', 'KOD']).sum()

# %%
sum
# Out:
#                 BODY_PH
# AIS_ID KOD
# 5635   AOVS_I    145.00
#        DPRS_I     26.00
#        VINF_I     62.00
# 5646   KOD_I      65.00
#        KPAIS_I    83.00
# ...                 ...
# 83074  ML1_B      78.50
#        OOP_B     166.00
#        PPI_B     124.24
#        PRPR_B     90.00
#        TZIV_B     68.50
#
# [9752 rows x 1 columns]

# %%
sum.loc[79814]
# Out:
#           BODY_PH
# KOD
# AJ_B        58.00
# IVZDEL_B    83.75
# SEMAP1_B    83.00
# SMAT1_B     74.50
# SMAT2_B     83.00
# UMA_B       65.00
# UMZI_B      67.00
# ZMTMO_B     80.50
# ZPRPR1_B    85.50
# ZPRPR2_B   104.00
# ZPS_B        7.00
# ZTIAPL_B    74.00

# %%
subject_points[subject_points['AIS_ID'] == 79814 ]
# Out:
#         OBDOBIE_ID       OBDOBIE       KOD  \
# 6021           409  ZS 2015/2016      AJ_B
# 6022           409  ZS 2015/2016      AJ_B
# 6023           409  ZS 2015/2016      AJ_B
# 6024           409  ZS 2015/2016      AJ_B
# 16763          409  ZS 2015/2016  IVZDEL_B
# ...            ...           ...       ...
# 103290         410  LS 2015/2016  ZTIAPL_B
# 103291         410  LS 2015/2016  ZTIAPL_B
# 103292         410  LS 2015/2016  ZTIAPL_B
# 103293         410  LS 2015/2016  ZTIAPL_B
# 103294         410  LS 2015/2016  ZTIAPL_B
#
#                                         PREDMET  LIST_ID  \
# 6021                             Anglický jazyk   170617
# 6022                             Anglický jazyk   170617
# 6023                             Anglický jazyk   170617
# 6024                             Anglický jazyk   170678
# 16763                    Informačné vzdelávanie   168209
# ...                                         ...      ...
# ...
